# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Pandas : Grouping and sorting

# %%
pokemon = pd.read_csv('pokemon.csv')
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
# we can use the groupby() function to a lot a things with respect to 
# sorting and grouping

# also we can replicate the value counts using groupby

pokemon.type_1.value_counts()

# this is the output when using value counts
# Out:
# water       114
# normal      105
# grass        78
# bug          72
# fire         53
# psychic      53
# rock         46
# electric     40
# poison       34
# ground       32
# dark         29
# fighting     29
# ghost        27
# dragon       27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: type_1, dtype: int64

# %%
# now trying to replicate the above using groupby

pokemon.groupby('type_1').type_1.count()

# here as we can see .. we get the same ouput as above.. only
# difference is that it not in any order but .. in above  case it was in descending
# order in terms of value counts
# Out:
# type_1
# bug          72
# dark         29
# dragon       27
# electric     40
# fairy        18
# fighting     29
# fire         53
# flying        3
# ghost        27
# grass        78
# ground       32
# ice          23
# normal      105
# poison       34
# psychic      53
# rock         46
# steel        24
# water       114
# Name: type_1, dtype: int64

# %% [markdown]
# __groupby()__ created a group of reviews which allottd the same point values to the given
# pokemon. Then , for each of these groups , we grabbed the __type_1__ column and counted
# how many items it appeared. __value_counts()__ is just a shortcut to this __groupby()__ operation.

# %%
# here what we have done is.. we are grouping the value by the type_1
# then we are getting the values of minimum heights of each type_1

pokemon.groupby('type_1').height.min()

# that is here bug type pokemon has minimum height of 0.1
# dragon type pokemon has the minimum height of 0.3
# Out:
# type_1
# bug         0.1
# dark        0.4
# dragon      0.3
# electric    0.2
# fairy       0.1
# fighting    0.5
# fire        0.4
# flying      0.5
# ghost       0.2
# grass       0.2
# ground      0.2
# ice         0.4
# normal      0.2
# poison      0.4
# psychic     0.1
# rock        0.3
# steel       0.2
# water       0.2
# Name: height, dtype: float64

# %% [markdown]
# you can think of each group we generate as being a slice of our dataframe containing only data with values that match. This DataFranme is accessible to us directly usint the __apply()__ method., and we can then manipulate the data in any way we see fit.For
# example|||

# %%
pokemon.groupby('type_1').apply(lambda df : df.height.min())

# here this is as same as the above .. but more flexible. 
# we can specify any rules inside the lambda
# Out:
# type_1
# bug         0.1
# dark        0.4
# dragon      0.3
# electric    0.2
# fairy       0.1
# fighting    0.5
# fire        0.4
# flying      0.5
# ghost       0.2
# grass       0.2
# ground      0.2
# ice         0.4
# normal      0.2
# poison      0.4
# psychic     0.1
# rock        0.3
# steel       0.2
# water       0.2
# dtype: float64

# %%
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
pokemon.groupby(['generation_id', 'type_1']).apply(lambda df : df.loc[df.attack.idxmax()])

# so here we can add more fine grained control..

# here we are picking out the best attacker in type_1 and in each generation
# Out:
#                          id       species  generation_id  height  weight  \
# generation_id type_1
# 1             bug       127        pinsir              1     1.5    55.0
#               dragon    149     dragonite              1     2.2   210.0
#               electric   26        raichu              1     0.8    30.0
#               fairy      36      clefable              1     1.3    40.0
#               fighting   68       machamp              1     1.6   130.0
#               fire      136       flareon              1     0.9    25.0
#               ghost      94        gengar              1     1.5    40.5
#               grass      71    victreebel              1     1.7    15.5
#               ground    112        rhydon              1     1.9   120.0
#               ice       144      articuno              1     1.7    55.4
#               normal     85        dodrio              1     1.8    85.2
#               poison     89           muk              1     1.2    30.0
#               psychic   150        mewtwo              1     2.0   122.0
#               rock       76         golem              1     1.4   300.0
#               water      99       kingler              1     1.3    60.0
# 2             bug       212        scizor              2     1.8   118.0
#               dark      215       sneasel              2     0.9    28.0
#               electric  243        raikou              2     1.9   178.0
#               fairy     210      granbull              2     1.4    48.7
#               fighting  237     hitmontop              2     1.4    48.0
#               fire      250         ho-oh              2     3.8   199.0
#               ghost     200    misdreavus              2     0.7     1.0
#               grass     154      meganium              2     1.8   100.5
#               ground    232       donphan              2     1.1   120.0
#               ice       221     piloswine              2     1.1    55.8
#               normal    217      ursaring              2     1.8   125.8
#               poison    169        crobat              2     1.8    75.0
#               psychic   251        celebi              2     0.6     5.0
#               rock      248     tyranitar              2     2.0   202.0
#               steel     208       steelix              2     9.2   400.0
# ...                     ...           ...            ...     ...     ...
# 6             electric  702       dedenne              6     0.2     2.2
#               fairy     716       xerneas              6     3.0   215.0
#               fighting  675       pangoro              6     2.1   136.0
#               fire      721     volcanion              6     1.7   195.0
#               flying    715       noivern              6     1.5    85.0
#               ghost     709     trevenant              6     1.5    71.0
#               grass     652    chesnaught              6     1.6    90.0
#               ice       713       avalugg              6     2.0   505.0
#               normal    676       furfrou              6     1.2    28.0
#               poison    691      dragalge              6     1.8    81.5
#               psychic   720         hoopa              6     0.5     9.0
#               rock      697     tyrantrum              6     2.5   270.0
#               steel     680      doublade              6     0.8     4.5
#               water     658      greninja              6     1.5    40.0
# 7             bug       794      buzzwole              7     2.4   333.6
#               dark      799      guzzlord              7     5.5   888.0
#               dragon    784       kommo-o              7     1.6    78.2
#               electric  785     tapu-koko              7     1.8    20.5
#               fairy     764        comfey              7     0.1     0.3
#               fighting  740  crabominable              7     1.7   180.0
#               fire      806   blacephalon              7     1.8    13.0
#               ghost     781      dhelmise              7     3.9   210.0
#               grass     798       kartana              7     0.3     0.1
#               ground    750      mudsdale              7     2.5   920.0
#               normal    760        bewear              7     2.1   135.0
#               poison    803       poipole              7     0.6     1.8
#               psychic   791      solgaleo              7     3.4   230.0
#               rock      805     stakataka              7     5.5   820.0
#               steel     797    celesteela              7     9.2   999.9
#               water     779       bruxish              7     0.9    19.0
#
#                         base_experience    type_1    type_2   hp  attack  \
# generation_id type_1
# 1             bug                   175       bug       NaN   65     125
#               dragon                270    dragon    flying   91     134
#               electric              218  electric       NaN   60      90
#               fairy                 217     fairy       NaN   95      70
#               fighting              227  fighting       NaN   90     130
#               fire                  184      fire       NaN   65     130
#               ghost                 225     ghost    poison   60      65
#               grass                 221     grass    poison   80     105
#               ground                170    ground      rock  105     130
#               ice                   261       ice    flying   90      85
#               normal                165    normal    flying   60     110
#               poison                175    poison       NaN  105     105
#               psychic               306   psychic       NaN  106     110
#               rock                  223      rock    ground   80     120
#               water                 166     water       NaN   55     130
# 2             bug                   175       bug     steel   70     130
#               dark                   86      dark       ice   55      95
#               electric              261  electric       NaN   90      85
#               fairy                 158     fairy       NaN   90     120
#               fighting              159  fighting       NaN   50      95
#               fire                  306      fire    flying  106     130
#               ghost                  87     ghost       NaN   60      60
#               grass                 236     grass       NaN   80      82
#               ground                175    ground       NaN   90     120
#               ice                   158       ice    ground  100     100
#               normal                175    normal       NaN   90     130
#               poison                241    poison    flying   85      90
#               psychic               270   psychic     grass  100     100
#               rock                  270      rock      dark  100     134
#               steel                 179     steel    ground   75      85
# ...                                 ...       ...       ...  ...     ...
# 6             electric              151  electric     fairy   67      58
#               fairy                 306     fairy       NaN  126     131
#               fighting              173  fighting      dark   95     124
#               fire                  270      fire     water   80     110
#               flying                187    flying    dragon   85      70
#               ghost                 166     ghost     grass   85     110
#               grass                 239     grass  fighting   88     107
#               ice                   180       ice       NaN   95     117
#               normal                165    normal       NaN   75      80
#               poison                173    poison    dragon   65      75
#               psychic               270   psychic     ghost   80     110
#               rock                  182      rock    dragon   82     121
#               steel                 157     steel     ghost   59     110
#               water                 239     water      dark   72      95
# 7             bug                   257       bug  fighting  107     139
#               dark                  257      dark    dragon  223     101
#               dragon                270    dragon  fighting   75     110
#               electric              257  electric     fairy   70     115
#               fairy                 170     fairy       NaN   51      52
#               fighting              167  fighting       ice   97     132
#               fire                  257      fire     ghost   53     127
#               ghost                 181     ghost     grass   70     131
#               grass                 257     grass     steel   59     181
#               ground                175    ground       NaN  100     125
#               normal                175    normal  fighting  120     125
#               poison                189    poison       NaN   67      73
#               psychic               306   psychic     steel  137     137
#               rock                  257      rock     steel   61     131
#               steel                 257     steel    flying   97     101
#               water                 166     water   psychic   68     105
#
#                         defense  speed  special-attack  special-defense
# generation_id type_1
# 1             bug           100     85              55               70
#               dragon         95     80             100              100
#               electric       55    110              90               80
#               fairy          73     60              95               90
#               fighting       80     55              65               85
#               fire           60     65              95              110
#               ghost          60    110             130               75
#               grass          65     70             100               70
#               ground        120     40              45               45
#               ice           100     85              95              125
#               normal         70    110              60               60
#               poison         75     50              65              100
#               psychic        90    130             154               90
#               rock          130     45              55               65
#               water         115     75              50               50
# 2             bug           100     65              55               80
#               dark           55    115              35               75
#               electric       75    115             115              100
#               fairy          75     45              60               60
#               fighting       95     70              35              110
#               fire           90     90             110              154
#               ghost          60     85              85               85
#               grass         100     80              83              100
#               ground        120     50              60               60
#               ice            80     50              60               60
#               normal         75     55              75               75
#               poison         80    130              70               80
#               psychic       100    100             100              100
#               rock          110     61              95              100
#               steel         200     30              55               65
# ...                         ...    ...             ...              ...
# 6             electric       57    101              81               67
#               fairy          95     99             131               98
#               fighting       78     58              69               71
#               fire          120     70             130               90
#               flying         80    123              97               80
#               ghost          76     56              65               82
#               grass         122     64              74               75
#               ice           184     28              44               46
#               normal         60    102              65               90
#               poison         90     44              97              123
#               psychic        60     70             150              130
#               rock          119     71              69               59
#               steel         150     35              45               49
#               water          67    122             103               71
# 7             bug           139     79              53               53
#               dark           53     43              97               53
#               dragon        125     85             100              105
#               electric       85    130              95               75
#               fairy          90    100              82              110
#               fighting       77     43              62               67
#               fire           53    107             151               79
#               ghost         100     40              86               90
#               grass         131    109              59               31
#               ground        100     35              55               85
#               normal         80     60              55               60
#               poison         67     73              73               67
#               psychic       107     97             113               89
#               rock          211     13              53              101
#               steel         103     61             107              101
#               water          70     92              70               70
#
# [114 rows x 14 columns]

# %% [markdown]
# another __groupby()__ method worth mentioning is __agg()__ , which lets you run a bunch of different functions on your DataFrame sumultaneously
#
# for egs we can generate a simple statistical summary as follows

# %%
pokemon.groupby(['type_1']).attack.agg([len,min,max])

# so here we can see that there are 72 total bug type_1 s.
# and minimum attack points of a pokemon in bug category is 10
#and maximum attack points of a pokemon in bug category is 139
#
# Out:
#           len  min  max
# type_1
# bug        72   10  139
# dark       29   50  131
# dragon     27   50  150
# electric   40   30  123
# fairy      18   20  131
# fighting   29   35  140
# fire       53   40  140
# flying      3   30  115
# ghost      27   30  131
# grass      78   27  181
# ground     32   40  150
# ice        23   30  130
# normal    105    5  160
# poison     34   43  106
# psychic    53   20  150
# rock       46   40  165
# steel      24   24  135
# water     114   10  130

# %% [markdown]
# # Multi-indexes

# %% [markdown]
# In all of example above we have been working with Dataframes or series objects with a single-label index.  __groupby()__ is slightly different in the fact that , depending on the operation we run , it will sometimes result in what is called a multi-index

# %%
# for egs

test_pok = pokemon.groupby(['type_1','type_2']).species.agg(len)
test_pok
# Out:
# type_1    type_2
# bug       electric     4
#           fairy        2
#           fighting     3
#           fire         2
#           flying      13
#           ghost        1
#           grass        6
#           ground       1
#           poison      11
#           rock         3
#           steel        5
#           water        3
# dark      dragon       4
#           fighting     2
#           fire         2
#           flying       5
#           ghost        1
#           ice          2
#           psychic      2
#           steel        2
# dragon    electric     1
#           fighting     2
#           fire         1
#           flying       4
#           ground       4
#           ice          1
#           psychic      2
# electric  fairy        2
#           flying       3
#           ghost        1
#                       ..
# rock      grass        2
#           ground       6
#           ice          2
#           poison       1
#           psychic      2
#           steel        4
#           water        6
# steel     dragon       1
#           fairy        3
#           fighting     1
#           flying       2
#           ghost        3
#           ground       1
#           psychic      6
#           rock         3
# water     bug          2
#           dark         4
#           dragon       2
#           electric     2
#           fairy        4
#           fighting     2
#           flying       7
#           ghost        2
#           grass        3
#           ground       9
#           ice          3
#           poison       3
#           psychic      5
#           rock         4
#           steel        1
# Name: species, Length: 141, dtype: int64

# %%
mi = test_pok.index
type(mi)

# here in the output we can see that it is given it is multi-index
# Out:
# pandas.core.indexes.multi.MultiIndex

# %% [markdown]
# so multi indices have several methods for dealing with their tiered structure which are absent for single - level indices. They also require two levels of labels to retrieve a value.
#
# In general the multi-index method you will use most often is the one converting back to regular indec, using __reset_index()__ method.

# %%
x = test_pok.reset_index()
x.head()
# Out:
#   type_1    type_2  species
# 0    bug  electric        4
# 1    bug     fairy        2
# 2    bug  fighting        3
# 3    bug      fire        2
# 4    bug    flying       13

# %%
y = x.index
type(y)

# now we can see that it shows range index
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# # Sorting

# %% [markdown]
# looking at the __test_pok__ we can see that grouping returns data in Index order, not in value order.This is to say , when outputing the result of a __groupby__ , the order of the rows is dependent on the values in the index, not in the data.
#
# to get data in the order we want it in, we can sort it ourselves , The __sort_values()__ method is handy for this.

# %%
# first reset the index
# then use dataframe.sort_values(by ='len')

# here my dataframe used here is not compatible with using sort_values

# %%
# this sort with index values..as we can see but the indexes are sorted according
# to index in alphabetic order
x.sort_index()
# Out:
#        type_1    type_2  species
# 0         bug  electric        4
# 1         bug     fairy        2
# 2         bug  fighting        3
# 3         bug      fire        2
# 4         bug    flying       13
# 5         bug     ghost        1
# 6         bug     grass        6
# 7         bug    ground        1
# 8         bug    poison       11
# 9         bug      rock        3
# 10        bug     steel        5
# 11        bug     water        3
# 12       dark    dragon        4
# 13       dark  fighting        2
# 14       dark      fire        2
# 15       dark    flying        5
# 16       dark     ghost        1
# 17       dark       ice        2
# 18       dark   psychic        2
# 19       dark     steel        2
# 20     dragon  electric        1
# 21     dragon  fighting        2
# 22     dragon      fire        1
# 23     dragon    flying        4
# 24     dragon    ground        4
# 25     dragon       ice        1
# 26     dragon   psychic        2
# 27   electric     fairy        2
# 28   electric    flying        3
# 29   electric     ghost        1
# ..        ...       ...      ...
# 111      rock     grass        2
# 112      rock    ground        6
# 113      rock       ice        2
# 114      rock    poison        1
# 115      rock   psychic        2
# 116      rock     steel        4
# 117      rock     water        6
# 118     steel    dragon        1
# 119     steel     fairy        3
# 120     steel  fighting        1
# 121     steel    flying        2
# 122     steel     ghost        3
# 123     steel    ground        1
# 124     steel   psychic        6
# 125     steel      rock        3
# 126     water       bug        2
# 127     water      dark        4
# 128     water    dragon        2
# 129     water  electric        2
# 130     water     fairy        4
# 131     water  fighting        2
# 132     water    flying        7
# 133     water     ghost        2
# 134     water     grass        3
# 135     water    ground        9
# 136     water       ice        3
# 137     water    poison        3
# 138     water   psychic        5
# 139     water      rock        4
# 140     water     steel        1
#
# [141 rows x 3 columns]

# %%
type(pok_test2.index)
type(pokemon.sort_values(by='len'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/conda1/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'len'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-828f4e222aca> in <module>
#       1 type(pok_test2.index)
# ----> 2 type(pokemon.sort_values(by='len'))
#
# ~/anaconda3/envs/conda1/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3617
#    3618             by = by[0]
# -> 3619             k = self.xs(by, axis=other_axis).values
#    3620             if k.ndim == 2:
#    3621
#
# ~/anaconda3/envs/conda1/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2333
#    2334         if axis == 1:
# -> 2335             return self[key]
#    2336
#    2337         self._consolidate_inplace()
#
# ~/anaconda3/envs/conda1/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/anaconda3/envs/conda1/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/envs/conda1/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/anaconda3/envs/conda1/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/envs/conda1/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'len'
