# %% [markdown]
# # How models work

# %%
# to read a csv file we use the help of pandas
import pandas as pd

# %%
# we use the below code to read csv

#home_data = pd.read_csv(filepath)

# %%
# selecting data for modeling

# to drop a row having missing data .. simply we type

# home_data = home_data.dropna(axis = 0)

# %% [markdown]
# # pandas

# %% [markdown]
# ## we are going to quickly brush up some important methods in pandas

# %% [markdown]
# ##  Indexing selecting and assigning

# %% [markdown]
# ## Naive accessors

# %%
pokemon = pd.read_csv('pokemon.csv')
pokemon.head()
# Out:
#    id     species  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
pokemon.iloc[0]
# this returns the first row with all the columns
# Out:
# id                         1
# species            bulbasaur
# generation_id              1
# height                   0.7
# weight                   6.9
# base_experience           64
# type_1                 grass
# type_2                poison
# hp                        45
# attack                    49
# defense                   49
# speed                     45
# special-attack            65
# special-defense           65
# Name: 0, dtype: object

# %%
# to access a particular columns and all its rows
pokemon.species.head()

# head is used to show only the first 5 rows
# Out:
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# 4    charmeleon
# Name: species, dtype: object

# %%
# or we can do the same above with this code.. the main difference is this can be
# used in all cases,, suppose if there is a space in column name. the former wont work . but this works
pokemon['species'].head()
# Out:
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# 4    charmeleon
# Name: species, dtype: object

# %%
pokemon['species'][0]

# this gets you a single value.. we provide the column number first and row number second
# Out:
# 'bulbasaur'

# %% [markdown]
# ## Indexing

# %%
# pandas has its own accessor operators .. loc and iloc
# this can be used for more advanced operations

# %% [markdown]
# ### index based selection

# %%
pokemon.iloc[0]

# this above code selects the first row of the dataframe
# Out:
# id                         1
# species            bulbasaur
# generation_id              1
# height                   0.7
# weight                   6.9
# base_experience           64
# type_1                 grass
# type_2                poison
# hp                        45
# attack                    49
# defense                   49
# speed                     45
# special-attack            65
# special-defense           65
# Name: 0, dtype: object

# %%
# both loc and iloc are row-first column second.. this is opposite to what we do
# native python .. which is column-first row-second

# this means its easier to retrieve rows ..but is marginally harder to retrieve columns

pokemon.iloc[:,1]

# this above code will get you a column species .. with all its 806 rows
# Out:
# 0        bulbasaur
# 1          ivysaur
# 2         venusaur
# 3       charmander
# 4       charmeleon
# 5        charizard
# 6         squirtle
# 7        wartortle
# 8        blastoise
# 9         caterpie
# 10         metapod
# 11      butterfree
# 12          weedle
# 13          kakuna
# 14        beedrill
# 15          pidgey
# 16       pidgeotto
# 17         pidgeot
# 18         rattata
# 19        raticate
# 20         spearow
# 21          fearow
# 22           ekans
# 23           arbok
# 24         pikachu
# 25          raichu
# 26       sandshrew
# 27       sandslash
# 28       nidoran-f
# 29        nidorina
#           ...
# 777        mimikyu
# 778        bruxish
# 779         drampa
# 780       dhelmise
# 781       jangmo-o
# 782       hakamo-o
# 783        kommo-o
# 784      tapu-koko
# 785      tapu-lele
# 786      tapu-bulu
# 787      tapu-fini
# 788         cosmog
# 789        cosmoem
# 790       solgaleo
# 791         lunala
# 792       nihilego
# ...

# %%
pokemon.iloc[:3,1]
# now by changing the row argument here we can decide which row or set or rows we need to retrieve
# Out:
# 0    bulbasaur
# 1      ivysaur
# 2     venusaur
# Name: species, dtype: object

# %%
pokemon.iloc[[0,1,2,3],1]
# we can also provide a list showing the index of the rows to retrieve the rows in 
# particular column
# Out:
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# Name: species, dtype: object

# %%
pokemon.iloc[[0,1,2,3],[1,2]]

# now we provided both rows and columns as lists
# Out:
#       species  generation_id
# 0   bulbasaur              1
# 1     ivysaur              1
# 2    venusaur              1
# 3  charmander              1

# %%
# we can also use negative indexing to retrieve from the last
pokemon.iloc[-5:]
# will retrieve you last 5 rows..with all its rows
# Out:
#       id      species  generation_id  height  weight  base_experience  \
# 802  803      poipole              7     0.6     1.8              189
# 803  804    naganadel              7     3.6   150.0              243
# 804  805    stakataka              7     5.5   820.0              257
# 805  806  blacephalon              7     1.8    13.0              257
# 806  807      zeraora              7     1.5    44.5              270
#
#        type_1  type_2  hp  attack  defense  speed  special-attack  \
# 802    poison     NaN  67      73       67     73              73
# 803    poison  dragon  73      73       73    121             127
# 804      rock   steel  61     131      211     13              53
# 805      fire   ghost  53     127       53    107             151
# 806  electric     NaN  88     112       75    143             102
#
#      special-defense
# 802               67
# 803               73
# 804              101
# 805               79
# 806               80

# %% [markdown]
# # Manipulating the Index

# %%
# the set_index() method can be used to set any column as the index column
# or in other way we can say that its the name of the rows.

pokemon.set_index('id').head()

# here i set the index as the contents in the column 'id'
# Out:
#        species  generation_id  height  weight  base_experience type_1  type_2  \
# id
# 1    bulbasaur              1     0.7     6.9               64  grass  poison
# 2      ivysaur              1     1.0    13.0              142  grass  poison
# 3     venusaur              1     2.0   100.0              236  grass  poison
# 4   charmander              1     0.6     8.5               62   fire     NaN
# 5   charmeleon              1     1.1    19.0              142   fire     NaN
#
#     hp  attack  defense  speed  special-attack  special-defense
# id
# 1   45      49       49     45              65               65
# 2   60      62       63     60              80               80
# 3   80      82       83     80             100              100
# 4   39      52       43     65              60               50
# 5   58      64       58     80              80               65

# %% [markdown]
# ## conditional selection

# %%
pokemon.type_1 == 'grass'
# this will go through all the rows of dataframe to show 
# the boolean output
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 777    False
# 778    False
# 779    False
# 780    False
# 781    False
# 782    False
# 783    False
# 784    False
# 785    False
# 786     True
# 787    False
# 788    False
# 789    False
# 790    False
# 791    False
# 792    False
# 793    False
# 794    False
# 795    False
# 796    False
# 797     True
# 798    False
# 799    False
# 800    False
# 801    False
# 802    False
# 803    False
# 804    False
# 805    False
# 806    False
# Name: type_1, Length: 807, dtype: bool

# %%
# this above result can be used inside the loc to select only the relevant data

pokemon.loc[pokemon.type_1 == 'grass']

# here this dataframe is 78*14 therefore 
# there are 78 pokemons having 'grass' as type_1
# Out:
#       id     species  generation_id  height  weight  base_experience type_1  \
# 0      1   bulbasaur              1     0.7     6.9               64  grass
# 1      2     ivysaur              1     1.0    13.0              142  grass
# 2      3    venusaur              1     2.0   100.0              236  grass
# 42    43      oddish              1     0.5     5.4               64  grass
# 43    44       gloom              1     0.8     8.6              138  grass
# 44    45   vileplume              1     1.2    18.6              221  grass
# 68    69  bellsprout              1     0.7     4.0               60  grass
# 69    70  weepinbell              1     1.0     6.4              137  grass
# 70    71  victreebel              1     1.7    15.5              221  grass
# 101  102   exeggcute              1     0.4     2.5               65  grass
# 102  103   exeggutor              1     2.0   120.0              186  grass
# ...

# %% [markdown]
# like wise we can use "and or" etc inside the loc to give out desirable outputs

# %%
# using isin inside loc to get values

pokemon.loc[pokemon.type_1.isin(['grass','fire'])]

# so using isin and providing a list we can search for multiple terms
# Out:
#       id      species  generation_id  height  weight  base_experience type_1  \
# 0      1    bulbasaur              1     0.7     6.9               64  grass
# 1      2      ivysaur              1     1.0    13.0              142  grass
# 2      3     venusaur              1     2.0   100.0              236  grass
# 3      4   charmander              1     0.6     8.5               62   fire
# 4      5   charmeleon              1     1.1    19.0              142   fire
# 5      6    charizard              1     1.7    90.5              240   fire
# 36    37       vulpix              1     0.6     9.9               60   fire
# 37    38    ninetales              1     1.1    19.9              177   fire
# 42    43       oddish              1     0.5     5.4               64  grass
# 43    44        gloom              1     0.8     8.6              138  grass
# 44    45    vileplume              1     1.2    18.6              221  grass
# ...

# %%
# using "isnull" and "notnull"

# this method will let you highlight which values are(are not) empty

pokemon.loc[pokemon.type_2.notnull()]

# so there are 405 pokemons for which type is not null value
# Out:
#       id      species  generation_id  height  weight  base_experience  \
# 0      1    bulbasaur              1     0.7     6.9               64
# 1      2      ivysaur              1     1.0    13.0              142
# 2      3     venusaur              1     2.0   100.0              236
# 5      6    charizard              1     1.7    90.5              240
# 11    12   butterfree              1     1.1    32.0              178
# 12    13       weedle              1     0.3     3.2               39
# 13    14       kakuna              1     0.6    10.0               72
# 14    15     beedrill              1     1.0    29.5              178
# 15    16       pidgey              1     0.3     1.8               50
# 16    17    pidgeotto              1     1.1    30.0              122
# 17    18      pidgeot              1     1.5    39.5              216
# 20    21      spearow              1     0.3     2.0               52
# ...

# %%
pokemon.loc[pokemon.type_2.isnull()]

# so there are 402 pokemons having type_2 as null values
# Out:
#       id     species  generation_id  height  weight  base_experience  \
# 3      4  charmander              1     0.6     8.5               62
# 4      5  charmeleon              1     1.1    19.0              142
# 6      7    squirtle              1     0.5     9.0               63
# 7      8   wartortle              1     1.0    22.5              142
# 8      9   blastoise              1     1.6    85.5              239
# 9     10    caterpie              1     0.3     2.9               39
# 10    11     metapod              1     0.7     9.9               72
# 18    19     rattata              1     0.3     3.5               51
# 19    20    raticate              1     0.7    18.5              145
# 22    23       ekans              1     2.0     6.9               58
# 23    24       arbok              1     3.5    65.0              157
# 24    25     pikachu              1     0.4     6.0              112
# 25    26      raichu              1     0.8    30.0              218
# ...

# %% [markdown]
# # Assigning Data

# %%
# so i am going to create a new column and assign data at the same time

pokemon['I_like'] = 'everyone'
pokemon

# now u can see that pokemon dataframe has one more column with value i like
# by keeping this is mind we can customized existing columns, particular rows and 
# assign desired values to it by tweaking the above code
# Out:
#       id      species  generation_id  height  weight  base_experience  \
# 0      1    bulbasaur              1     0.7     6.9               64
# 1      2      ivysaur              1     1.0    13.0              142
# 2      3     venusaur              1     2.0   100.0              236
# 3      4   charmander              1     0.6     8.5               62
# 4      5   charmeleon              1     1.1    19.0              142
# 5      6    charizard              1     1.7    90.5              240
# 6      7     squirtle              1     0.5     9.0               63
# 7      8    wartortle              1     1.0    22.5              142
# 8      9    blastoise              1     1.6    85.5              239
# 9     10     caterpie              1     0.3     2.9               39
# 10    11      metapod              1     0.7     9.9               72
# 11    12   butterfree              1     1.1    32.0              178
# ...

# %%
# creating a pandas series object from a column of pokmon

pokemon_names = pokemon.species
pokemon_names
# Out:
# 0        bulbasaur
# 1          ivysaur
# 2         venusaur
# 3       charmander
# 4       charmeleon
# 5        charizard
# 6         squirtle
# 7        wartortle
# 8        blastoise
# 9         caterpie
# 10         metapod
# 11      butterfree
# 12          weedle
# 13          kakuna
# 14        beedrill
# 15          pidgey
# 16       pidgeotto
# 17         pidgeot
# 18         rattata
# 19        raticate
# 20         spearow
# 21          fearow
# 22           ekans
# 23           arbok
# 24         pikachu
# 25          raichu
# 26       sandshrew
# 27       sandslash
# 28       nidoran-f
# 29        nidorina
#           ...
# 777        mimikyu
# 778        bruxish
# 779         drampa
# 780       dhelmise
# 781       jangmo-o
# 782       hakamo-o
# 783        kommo-o
# 784      tapu-koko
# 785      tapu-lele
# 786      tapu-bulu
# 787      tapu-fini
# 788         cosmog
# 789        cosmoem
# 790       solgaleo
# 791         lunala
# 792       nihilego
# ...

# %%
# asssigning the first species name to a variable
first_pokemon = pokemon['species'][0]
print(first_pokemon)

# or

second_pokemon = pokemon.species.iloc[1]
print(second_pokemon)

#or

third_pokemon = pokemon.species[2]
print(third_pokemon)
# Out:
# bulbasaur
# ivysaur
# venusaur

# %%
first_row = pokemon.iloc[0]
print(first_row)
# Out:
# id                         1
# species            bulbasaur
# generation_id              1
# height                   0.7
# weight                   6.9
# base_experience           64
# type_1                 grass
# type_2                poison
# hp                        45
# attack                    49
# defense                   49
# speed                     45
# special-attack            65
# special-defense           65
# I_like              everyone
# Name: 0, dtype: object

# %%
first10 = pokemon.species.iloc[0:10]
print(first10)

# or 

first_10 = pokemon.species.head(10)
print(first_10)

# OR 
FIRST10 = pokemon.loc[:9, "species"]
print(FIRST10)


# here we can see some differeneces betweeen loc and iloc
# for iloc the correct indexing is needed to perfom that is [0:10]
# here it includes 0 and excludes 10

# but in loc we are pointing at an index location 
# so here to get the same value as above
# it should [:9]
# Out:
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# 4    charmeleon
# 5     charizard
# 6      squirtle
# 7     wartortle
# 8     blastoise
# 9      caterpie
# Name: species, dtype: object
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# 4    charmeleon
# 5     charizard
# 6      squirtle
# 7     wartortle
# 8     blastoise
# 9      caterpie
# Name: species, dtype: object
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# 4    charmeleon
# 5     charizard
# 6      squirtle
# 7     wartortle
# 8     blastoise
# 9      caterpie
# Name: species, dtype: object

# %%
# hmm interesting!!!
first10 + " "+ first_10
# Out:
# 0      bulbasaur bulbasaur
# 1          ivysaur ivysaur
# 2        venusaur venusaur
# 3    charmander charmander
# 4    charmeleon charmeleon
# 5      charizard charizard
# 6        squirtle squirtle
# 7      wartortle wartortle
# 8      blastoise blastoise
# 9        caterpie caterpie
# Name: species, dtype: object

# %%
# i loc should only contain the index number only
# for egs for getting first 10 records of pokemon with only species column

pokemon.iloc[:10,1]
# here 1 represents the column number

# [rows, columns]
# Out:
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# 4    charmeleon
# 5     charizard
# 6      squirtle
# 7     wartortle
# 8     blastoise
# 9      caterpie
# Name: species, dtype: object

# %%
# similarly
# inside loc we can specify the column name

pokemon.loc[:9,'species']
# Out:
# 0     bulbasaur
# 1       ivysaur
# 2      venusaur
# 3    charmander
# 4    charmeleon
# 5     charizard
# 6      squirtle
# 7     wartortle
# 8     blastoise
# 9      caterpie
# Name: species, dtype: object

# %%
# create a new dataframe that contains type_1 as grass only

grass_pokemons = pokemon.loc[pokemon.type_1 == 'grass']
grass_pokemons

# or 

grasspok = pokemon[pokemon.type_1 =='grass']
grasspok
# Out:
#       id     species  generation_id  height  weight  base_experience type_1  \
# 0      1   bulbasaur              1     0.7     6.9               64  grass
# 1      2     ivysaur              1     1.0    13.0              142  grass
# 2      3    venusaur              1     2.0   100.0              236  grass
# 42    43      oddish              1     0.5     5.4               64  grass
# 43    44       gloom              1     0.8     8.6              138  grass
# 44    45   vileplume              1     1.2    18.6              221  grass
# 68    69  bellsprout              1     0.7     4.0               60  grass
# 69    70  weepinbell              1     1.0     6.4              137  grass
# 70    71  victreebel              1     1.7    15.5              221  grass
# 101  102   exeggcute              1     0.4     2.5               65  grass
# 102  103   exeggutor              1     2.0   120.0              186  grass
# ...

# %%
pokemon.describe()
# Out:
#                id  generation_id      height      weight  base_experience  \
# count  807.000000     807.000000  807.000000  807.000000       807.000000
# mean   404.000000       3.714994    1.162454   61.771128       144.848823
# std    233.105126       1.944148    1.081030  111.519355        74.953116
# min      1.000000       1.000000    0.100000    0.100000        36.000000
# 25%    202.500000       2.000000    0.600000    9.000000        66.000000
# 50%    404.000000       4.000000    1.000000   27.000000       151.000000
# 75%    605.500000       5.000000    1.500000   63.000000       179.500000
# max    807.000000       7.000000   14.500000  999.900000       608.000000
#
#                hp      attack     defense       speed  special-attack  \
# count  807.000000  807.000000  807.000000  807.000000      807.000000
# mean    68.748451   76.086741   71.726146   65.830235       69.486989
# std     26.032808   29.544598   29.730228   27.736838       29.439715
# ...

# %%
# create a dataframe having pokemon heights greater than 2
# and type one is only grass and fire

new_dataframe = pokemon[(pokemon.type_1.isin(['grass','fire'])) & (pokemon.height>=2)]
print(new_dataframe)

# so here we can see that we are using and to specify a particular thing
# always remember to use "&" instead of "and"..
# similarly "|" instead of "or"

print(" \n \n Total number of species are ", new_dataframe.id.count())
# Out:
#       id     species  generation_id  height  weight  base_experience type_1  \
# 2      3    venusaur              1     2.0   100.0              236  grass
# 102  103   exeggutor              1     2.0   120.0              186  grass
# 145  146     moltres              1     2.0    60.0              261   fire
# 243  244       entei              2     2.1   198.0              261   fire
# 249  250       ho-oh              2     3.8   199.0              306   fire
# 356  357     tropius              3     2.0   100.0              161  grass
# 388  389    torterra              4     2.2   310.0              236  grass
# 459  460   abomasnow              4     2.2   135.5              173  grass
# 464  465   tangrowth              4     2.0   128.6              187  grass
# 496  497   serperior              5     3.3    63.0              238  grass
# 639  640    virizion              5     2.0   200.0              261  grass
# ...
